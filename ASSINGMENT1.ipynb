# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#How many data-points and features

haberman=pd.read_csv("haberman.csv")
haberman.shape
# Out:
# (306, 4)

# %%
#Number of classes
haberman["status"].nunique()
# Out:
# 2

# %%
#Number of data-points in each class
haberman.count()
# Out:
# age       306
# year      306
# nodes     306
# status    306
# dtype: int64

# %%
#PDF curve
counts,bin_edges=np.histogram(haberman["age"],bins=10,density=True,)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b780b1be24e0> in <module>
#       1 #PDF curve
# ----> 2 counts,bin_edges=np.histogram(haberman["age"],bins=10,density=True,hue="status")
#       3 pdf=counts/sum(counts)
#       4 cdf=np.cumsum(pdf)
#       5 plt.plot(bin_edges[1:],pdf)
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# TypeError: _histogram_dispatcher() got an unexpected keyword argument 'hue'

# %%
counts,bin_edges=np.histogram(haberman["year"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# %%
counts,bin_edges=np.histogram(haberman["nodes"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,'-b',label='1')
plt.plot(bin_edges[1:],cdf,'--r',label='2')
plt.legend()

# %%
sns.boxplot(x='status',y='age',data=haberman)

# %%
sns.boxplot(x='status',y='year',data=haberman)

# %%
sns.boxplot(x='status',y='nodes',data=haberman)

# %%
sns.violinplot(x='status',y='age',data=haberman)

# %%
sns.violinplot(x='status',y='year',data=haberman)

# %%
sns.violinplot(x='status',y='nodes',data=haberman)

# %%
#Pair Plots
sns.set_style("whitegrid")
sns.pairplot(haberman,hue='status',size=4)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(haberman,hue='status',size=4)\
.map(plt.scatter,"age","nodes")\
.add_legend()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
